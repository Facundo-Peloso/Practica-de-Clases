# %%
import pandas as pd

# %%
arbolado = pd.read_csv('../Data/arbolado-publico-lineal-2017-2018.csv')
arbolado.head(3)
# Out:
# c:\Users\fpeloso\Anaconda3\envs\dhdsblend2021\lib\site-packages\IPython\core\interactiveshell.py:3135: DtypeWarning: Columns (2,7,8) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#         long        lat nro_registro tipo_activ  comuna manzana  \
# 0 -58.378563 -34.594902        26779     Lineal       1     NaN
# 1 -58.381532 -34.592319        30887     Lineal       1     NaN
# 2 -58.379103 -34.591939        30904     Lineal       1     NaN
#
#         calle_nombre calle_altura calle_chapa    direccion_normalizada  \
# 0          Esmeralda         1000        1120           ESMERALDA 1120
# 1  Pellegrini Carlos         1300        1345  PELLEGRINI, CARLOS 1345
# 2             Arroyo          800         848               ARROYO 848
#
#   ubicacion       nombre_cientifico ancho_acera estado_plantera  \
# 0       NaN            Tipuana tipu         5.5         Ocupada
# ...

# %%
arbolado.tail()
# Out:
#         long  lat nro_registro tipo_activ  comuna manzana calle_nombre  \
# 370175   NaN  NaN       546140    Lineal       15     919      Guevara
# 370176   NaN  NaN       546141    Lineal       15     919      Guevara
# 370177   NaN  NaN       546142    Lineal       15     919      Guevara
# 370178   NaN  NaN       546143    Lineal       15     919      Guevara
# 370179   NaN  NaN       546144    Lineal       15     919      Guevara
#
#        calle_altura calle_chapa direccion_normalizada ubicacion  \
# 370175         1000      1000.0                   NaN       LD3
# 370176         1000      1000.0                   NaN       LD4
# 370177         1000      1000.0                   NaN       LD5
# 370178         1000      1000.0                   NaN       LD6
# 370179         1000      1000.0                   NaN       LD7
#
#        nombre_cientifico ancho_acera estado_plantera ubicacion_plantera  \
# 370175    Ceiba speciosa         3.3         Ocupada            Regular
# ...

# %%
#en donde faltan datos
arbolado.isnull().sum()/arbolado.shape[0]*100
# Out:
# long                      4.144470
# lat                       4.144470
# nro_registro              0.000000
# tipo_activ                0.000000
# comuna                    0.000000
# manzana                  39.451078
# calle_nombre              0.025123
# calle_altura              1.486574
# calle_chapa               1.744827
# direccion_normalizada     3.846507
# ubicacion                 2.241072
# nombre_cientifico         0.000000
# ancho_acera               0.836620
# estado_plantera           0.000000
# ubicacion_plantera        0.379275
# nivel_plantera            0.365228
# diametro_altura_pecho     0.077260
# altura_arbol              1.167540
# dtype: float64

# %%
arbolado.sample(20)
# Out:
#              long        lat nro_registro tipo_activ  comuna manzana  \
# 38988  -58.399536 -34.638680       360218     Lineal       4     290
# 77313  -58.446944 -34.607820        44422     Lineal       6     NaN
# 170685 -58.467516 -34.654609       535909    Lineal        9    1195
# 296812 -58.473388 -34.539870       134433     Lineal      13       1
# 19453  -58.403856 -34.608760        25174     Lineal       3     NaN
# 184666 -58.523271 -34.631305       345454     Lineal      10     958
# 230438 -58.518204 -34.614350       262945     Lineal      11     712
# 202498 -58.502190 -34.619270       538788     Lineal      10    257a
# 26641  -58.393994 -34.615890        36878     Lineal       3     NaN
# 128755 -58.488450 -34.668532       522941     Lineal       8     119
# 36165  -58.400829 -34.630813       340640     Lineal       4     195
# 279963 -58.440400 -34.555521       101053     Lineal      13     NaN
# 273961 -58.486891 -34.556350       417463     Lineal      12     361
# ...

# %%
#voy a tirar la columna de manzanas , ya que tiene muchos datos faltantes y no es tan importante

#otra columna para tirar seria ubicación, porque no se interpretarla bien

#aca saco la columna manzana

#ahora lo saco
#arbolado.drop(columns=['manzana'], axis=1)

#vuelve a aparecer manzana

arbolado.head()


#porque drop genera una copia modificada

#no la vuelvo a ejecutar porque manzana¿ ya no existe
#  arbolado.drop(columns=['manzana'], axis=1, inplace=True)

arbolado.head()
# Out:
#         long        lat nro_registro tipo_activ  comuna       calle_nombre  \
# 0 -58.378563 -34.594902        26779     Lineal       1          Esmeralda
# 1 -58.381532 -34.592319        30887     Lineal       1  Pellegrini Carlos
# 2 -58.379103 -34.591939        30904     Lineal       1             Arroyo
# 3 -58.380710 -34.591548        31336     Lineal       1             Arroyo
# 4 -58.380710 -34.591548        31337     Lineal       1             Arroyo
#
#   calle_altura calle_chapa    direccion_normalizada ubicacion  \
# 0         1000        1120           ESMERALDA 1120       NaN
# 1         1300        1345  PELLEGRINI, CARLOS 1345    Exacta
# 2          800         848               ARROYO 848    Exacta
# 3          900         932               ARROYO 932        LD
# 4          900         932               ARROYO 932        LA
#
#         nombre_cientifico ancho_acera estado_plantera ubicacion_plantera  \
# ...

# %%
#tirar todos los registros donde haya mas de tres columnas sin datos

arbolado_limpio=arbolado.dropna(thresh=(arbolado.shape[1]-3))

print(arbolado_limpio.shape[0])

arbolado.shape[0]

arbolado_limpio.head()
# Out:
# 366931
#         long        lat nro_registro tipo_activ  comuna       calle_nombre  \
# 0 -58.378563 -34.594902        26779     Lineal       1          Esmeralda
# 1 -58.381532 -34.592319        30887     Lineal       1  Pellegrini Carlos
# 2 -58.379103 -34.591939        30904     Lineal       1             Arroyo
# 3 -58.380710 -34.591548        31336     Lineal       1             Arroyo
# 4 -58.380710 -34.591548        31337     Lineal       1             Arroyo
#
#   calle_altura calle_chapa    direccion_normalizada ubicacion  \
# 0         1000        1120           ESMERALDA 1120       NaN
# 1         1300        1345  PELLEGRINI, CARLOS 1345    Exacta
# 2          800         848               ARROYO 848    Exacta
# 3          900         932               ARROYO 932        LD
# 4          900         932               ARROYO 932        LA
#
#         nombre_cientifico ancho_acera estado_plantera ubicacion_plantera  \
# ...

# %%
arbolado['calle_altura'].fillna(arbolado['calle_chapa'], inplace= True)

arbolado['calle_chapa'].fillna(arbolado['calle_altura'], inplace=True)
arbolado.sample(10)

arbolado.isnull().sum()/arbolado.shape[0]*100
# Out:
# long                     4.144470
# lat                      4.144470
# nro_registro             0.000000
# tipo_activ               0.000000
# comuna                   0.000000
# calle_nombre             0.025123
# calle_altura             0.514074
# calle_chapa              0.514074
# direccion_normalizada    3.846507
# ubicacion                2.241072
# nombre_cientifico        0.000000
# ancho_acera              0.836620
# estado_plantera          0.000000
# ubicacion_plantera       0.379275
# nivel_plantera           0.365228
# diametro_altura_pecho    0.077260
# altura_arbol             1.167540
# dtype: float64

# %%
#ahora hacemos otro ejemplo dejando de lado ejemplos de fillna

#apply ahora

def cuadrado(x): 
    print(x*x)

# %%
cuadrado(3)
# Out:
# 9

# %%
cuadrado2=lambda x,y: print(x*y)

# %%
cuadrado2(3,10) #ejemplo de lambda
# Out:
# 30

# %%
arbolado['diametro_altura_pecho']>arbolado['altura_arbol']
# Out:
# 0          True
# 1          True
# 2          True
# 3         False
# 4          True
#           ...
# 370175     True
# 370176     True
# 370177     True
# 370178     True
# 370179     True
# Length: 370180, dtype: bool

# %%
arbolado['condicion']= arbolado['diametro_altura_pecho']>arbolado['altura_arbol']

# %%
arbolado['diametro_altura_pecho'].apply(lambda x : type(x))
# Out:
# 0         <class 'float'>
# 1         <class 'float'>
# 2         <class 'float'>
# 3         <class 'float'>
# 4         <class 'float'>
#                ...
# 370175    <class 'float'>
# 370176    <class 'float'>
# 370177    <class 'float'>
# 370178    <class 'float'>
# 370179    <class 'float'>
# Name: diametro_altura_pecho, Length: 370180, dtype: object

# %%
arbolado['diametro_altura_pecho'].apply(lambda x : x if x<10 else x*x)
# Out:
# 0         7744.0
# 1            6.0
# 2            7.0
# 3            9.0
# 4          169.0
#            ...
# 370175    1156.0
# 370176    2025.0
# 370177    3600.0
# 370178    4096.0
# 370179    3721.0
# Name: diametro_altura_pecho, Length: 370180, dtype: float64

# %%
arbolado.apply(lambda x: x['ancho_acera'] , axis=1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\fpeloso\Digital House\Prácticas mías\Practica-de-Clases\clase_09\dsad_2021\M2\CLASE_09_LimpiezaDeDatos\Notebooks\ejemplo-nuestro.ipynb Celda 17 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/fpeloso/Digital%20House/Pr%C3%A1cticas%20m%C3%ADas/Practica-de-Clases/clase_09/dsad_2021/M2/CLASE_09_LimpiezaDeDatos/Notebooks/ejemplo-nuestro.ipynb#X22sZmlsZQ%3D%3D?line=0'>1</a> arbolado.apply(lambda x: x['ancho_acera']*x['altura_arbol'] , axis=1)
#
# File c:\Users\fpeloso\Anaconda3\envs\dhdsblend2021\lib\site-packages\pandas\core\frame.py:7552, in DataFrame.apply(self, func, axis, raw, result_type, args, **kwds)
#    7541 from pandas.core.apply import frame_apply
#    7543 op = frame_apply(
#    7544     self,
#    7545     func=func,
#    (...)
#    7550     kwds=kwds,
#    7551 )
# ...
