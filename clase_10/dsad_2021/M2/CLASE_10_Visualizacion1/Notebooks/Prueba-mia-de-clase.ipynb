# %%
import pandas as pd

# %%
arbolado=pd.read_csv("../Data/arbolado.csv")
# Out:
# c:\Users\fpeloso\Anaconda3\envs\dhdsblend2021\lib\site-packages\IPython\core\interactiveshell.py:3135: DtypeWarning: Columns (2,7,8) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
especies = arbolado['nombre_cientifico'].value_counts().index[:3].to_list()
arbolado = arbolado[arbolado['nombre_cientifico'].isin(especies)]



#sns.scatterplot(data=arbolado,x='altura_arbol',y='diametro')

# %%
sns.set_style('darkgrid')
fig=plt.figure(figsize=(6,8))
ax=plt.axes()

sns.scatterplot(data=arbolado, x='nombre_cientifico',y='altura_arbol')
# Out:
# <AxesSubplot:xlabel='nombre_cientifico', ylabel='altura_arbol'>

# %%
sns.boxplot(data=arbolado, x='nombre_cientifico',y='altura_arbol')
# Out:
# <AxesSubplot:xlabel='nombre_cientifico', ylabel='altura_arbol'>

# %%
fig=plt.figure(figsize=(8,6))

sns.displot(data=arbolado, x='altura_arbol',stat='probability', hue='nombre_cientifico',multiple='stack')
